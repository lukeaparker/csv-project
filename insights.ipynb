# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('Health_AnimalBites.csv')
# Charted frequency Dog: 78%, cat: 17%, Other: 5% 
df['SpeciesIDDesc'].value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
# Charted frequency Male: 43%, Female: 29%, Unknown: 28% 
df['GenderIDDesc'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Charted frequency 1 year: 2894, 3 year: 837, 11 year: 1
df['vaccination_yrs'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='vaccination_yrs'>
